# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных." data-toc-modified-id="Обзор-данных.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных.</a></span><ul class="toc-item"><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных.</a></span></li><li><span><a href="#Исследовательский-анализ-данных." data-toc-modified-id="Исследовательский-анализ-данных.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных.</a></span><ul class="toc-item"><li><span><a href="#Средние-значения-признаков." data-toc-modified-id="Средние-значения-признаков.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Средние значения признаков.</a></span></li><li><span><a href="#Гистограммы-и-распределения-признаков." data-toc-modified-id="Гистограммы-и-распределения-признаков.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Гистограммы и распределения признаков.</a></span></li><li><span><a href="#Матрица-корреляций." data-toc-modified-id="Матрица-корреляций.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Матрица корреляций.</a></span></li></ul></li><li><span><a href="#Модели-прогнозирования-оттока-пользователей." data-toc-modified-id="Модели-прогнозирования-оттока-пользователей.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Модели прогнозирования оттока пользователей.</a></span><ul class="toc-item"><li><span><a href="#Предобрадобка-данных-для-модели." data-toc-modified-id="Предобрадобка-данных-для-модели.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Предобрадобка данных для модели.</a></span></li><li><span><a href="#Обучение--модели." data-toc-modified-id="Обучение--модели.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучение  модели.</a></span></li></ul></li><li><span><a href="#Кластеризация-пользователей." data-toc-modified-id="Кластеризация-пользователей.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Кластеризация пользователей.</a></span><ul class="toc-item"><li><span><a href="#Обучение-модели." data-toc-modified-id="Обучение-модели.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Обучение модели.</a></span></li><li><span><a href="#Анализ-кластеров-клиентов." data-toc-modified-id="Анализ-кластеров-клиентов.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ кластеров клиентов.</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации-по-работе-с-клиентами." data-toc-modified-id="Выводы-и-рекомендации-по-работе-с-клиентами.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы и рекомендации по работе с клиентами.</a></span></li></ul></div>

# %% [markdown]
# # Прогнозирование оттока клиентов фитнес-центров «Культурист-датасаентист»

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с пользователями на основе аналитических данных. Отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество анкет пользователей (данные предоставил в виде csv-файла 'gym_churn.csv'.
#
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Как понять, что пользователь больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
#
# Цель: провести анализ и подготовить план действий по удержанию клиентов (сокращению оттока).
#
# Для фитнес-центра клиент попал в отток, если за последний месяц ни разу не посетил спортзал.
#
# Для достижения цели решим следующие задачи:
# - научимся прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# - сформируем типичные портреты пользователей: выделим несколько наиболее ярких групп и охарактеризуем их основные свойства;
# - проанализируем основные признаки, наиболее сильно влияющие на отток;
# - сформулируем основные выводы и разработаем рекомендации по повышению качества работы с клиентами.

# %% [markdown]
# ## Обзор данных.

# %% [markdown]
# «Культурист-датасаентист» предоставил сведения в csv-файле. Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц.
#
# Набор данных включает следующие поля:
# `Churn` — факт оттока в текущем месяце;
#
# Данные пользователя за предыдущий до проверки факта оттока месяц:
#
# - `gender` — пол
# - `Near_Location` — проживание или работа в районе, где находится фитнес-центр
# - `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента)
# - `Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента)
# - `Phone` — наличие контактного телефона
# - `Age` — возраст
# - `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах)
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента
#
# - `Contract_period` — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год)
# - `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах)
# - `Group_visits` — факт посещения групповых занятий
# - `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента
# - `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц
# - `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон.

# %%
import pandas as pd 
import numpy as np 
import scipy.stats as st
import os 
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
 

pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_colwidth = 130

# %%
def read_file(file, number):
    '''Функция обзора данных. 
       file - имя файла в формате 'xxxx.csv'
       number - целое число.
       Считывает файл из облака Яндекс.Практикума или из домашнего каталога с ноутбуком.
       Выводит на экран number-строк датафрейма и общую информацию о количестве строк и типах данных.   
    '''

    if os.path.exists('/datasets/' + file): # проверка наличия файла в облаке
        df = pd.read_csv('/datasets/' + file) # чтение файла с данными и сохранение
    else:
        try:
            df = pd.read_csv(file)
        except:
            display('Проверьте наличие файла на локальном хранилище!')
    
    display(df.head(number))  
    print()
    display(df.info())
    print()
    
    # подсчет уникальных значений по столбцу и вывод их на экран (если количество не превышает 100)
    for col in df.columns:
        print( col, df[col].nunique())
        if df[col].nunique() < 100:
            print(df[col].sort_values().unique())
        print()
    
    print('Количество дубликатов', df.duplicated().sum())
    
    shape = df.shape
    
    return df, shape

# %%
df, shape_df = read_file('gym_churn.csv', 10)
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
# 5       1              1        0              0      1                1
# 6       1              1        1              1      0                6
# 7       0              1        0              0      1                1
# 8       1              1        1              1      1                1
# 9       0              1        0              0      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                         14.23                   5.00
# ...

# %% [markdown]
# В датасете 4000 наблюдейний и 13 признаков (6 из них категориальные) + 1 целевая переменная. Пропусков в данных нет. Признак "количество месяцев до окончания контракта" представлен вещественным числом, но принимает три целочисленных значения 1, 6 и 12 месяцев - необходимо преобразовать. Категориальные признаки закодированы 0 и 1 - не требуют дополнительной обработки. Привязки ко времени у признаков нет.

# %%
# посмотрим на гистограммы распределения признаков
for col in df.columns:
    df[col].hist(bins=50)
    plt.title(col)
    plt.xlabel('Значения переменной')
    plt.ylabel('Кол-во')
    # посчитаем долю значений
    display(df.groupby(col)[col].count() / df[col].count() * 100)
    plt.show()
# Out:
# gender
# 0   48.98
# 1   51.02
# Name: gender, dtype: float64
# Near_Location
# 0   15.47
# 1   84.52
# Name: Near_Location, dtype: float64
# Partner
# 0   51.32
# 1   48.68
# Name: Partner, dtype: float64
# Promo_friends
# 0   69.15
# 1   30.85
# Name: Promo_friends, dtype: float64
# Phone
# 0    9.65
# 1   90.35
# Name: Phone, dtype: float64
# Contract_period
# 1    55.17
# 6    20.82
# 12   24.00
# Name: Contract_period, dtype: float64
# Group_visits
# 0   58.77
# 1   41.23
# Name: Group_visits, dtype: float64
# Age
# 18    0.05
# 19    0.05
# 20    0.35
# 21    0.60
# 22    0.83
# 23    2.05
# 24    3.70
# 25    5.78
# 26    7.50
# 27    9.45
# 28   11.18
# 29   11.70
# 30   11.43
# 31   10.85
# 32    9.10
# 33    6.33
# 34    4.35
# 35    2.45
# 36    1.20
# 37    0.73
# 38    0.25
# 39    0.07
# 41    0.03
# Name: Age, dtype: float64
# Avg_additional_charges_total
# 0.15     0.03
# 0.17     0.03
# 0.25     0.03
# 0.33     0.03
# 0.36     0.03
#          ...
# 488.71   0.03
# ...

# %% [markdown]
# - В данных предсталены примерно равное количество записей по мужчинам и женщинам. Пол закодирован, расшифровка в документации не дана.
# - Распределение возраста клиентов имеет вид нормального. Клиентами являются люди в возрасте от 18 до 41 года.
# - 85% клиентов проживают в непосредственой близости к фитнес-центру. Примерно половина клиентов имеет скидку партнера. Треть клиентов пришли по приглашению друга. 90% клиентов оставляют контактный номер телефона.
# - Среди действующих абонементов 55% на месяц, 21% на 6 месяцев и  24% на 12 месяцев. Абонементом на 3 месяца не пользуется никто.
# - Распределение количества месяцев до кончания абонемента имеет ожидаемый пик на значении 1 месяц. Далее представлены все значения до 12 с пиками в 6 и 12. 13% клиентов купили абонемент на год в отчетном месяце.
# - Лайфтайм представляет собой скшенное нармальное распределение. 12% клиентов - новые, 21% являются клиентами больше месяца. Далее удержание падает. Существуют клиенты, посещающие центр более года и даже более 2 лет.
# - 40% клиентов посещают групповые занятия. Средняя частота посещений в неделю за все время с начала действия абонемента имеет вид нормального распределения, я выраженным ожидаемым пиков в 0 (для непосещающих групповые занятия клиентов). Более 4 раз в неделю радко кто ходит. Аналогичная характеристика и за последний месяц.
# - Расходы клиентов на дополнительный услуги ожидаемо представляют собой скошенное нормальное распределение. Есть группа, пользующаяся минимальным набором дополнительных услуг. Большая часть клиентов готова платить до 200 у.е. Далее количество клиентов устойчиво снижается. Более 400 у.е. заплатила очень маленькая часть (хвост распределения). Необычно, что нет клиентов, которые вообще не платят за доп. услуги.
# - В отток ушло 26.5% клиентов.

# %%
# определим числовые признаки и посмотрим на статистики
numeric_col = ['Age',
       'Avg_additional_charges_total', 'Lifetime',
       'Avg_class_frequency_total', 'Avg_class_frequency_current_month']
df[numeric_col].describe(percentiles=[.25,.50,.75,.95,.99])
# Out:
#           Age  Avg_additional_charges_total  Lifetime  \
# count 4000.00                       4000.00   4000.00
# mean    29.18                        146.94      3.72
# std      3.26                         96.36      3.75
# min     18.00                          0.15      0.00
# 25%     27.00                         68.87      1.00
# 50%     29.00                        136.22      3.00
# 75%     31.00                        210.95      5.00
# 95%     34.00                        323.44     11.00
# 99%     37.00                        401.00     17.00
# max     41.00                        552.59     31.00
#
#        Avg_class_frequency_total  Avg_class_frequency_current_month
# count                    4000.00                            4000.00
# mean                        1.88                               1.77
# std                         0.97                               1.05
# min                         0.00                               0.00
# ...

# %% [markdown]
# - Средний возраст клиентов 29 лет. 50% клиентов от 27 до 31 года. Стандартное отклонение равно 3 годам, что значительно меньше среднего - распределение достаточно компактно.
# - Среднее время посещения центра клиентами 3.72 месяца, при этом более 5 месяцев спортом занимаются только 25% клиентов. Лояльность более 17 месяцев характерна только для 1% клиентов. Стандартное отклонение чуть больше среднего, что свидетельствует о достаточном размахе в значениях (от 0 до 31).
# - Средняя частота посещений колеблется от 1.77 за последний месяц до 1.88 за все время действия абонемента. 25% клиентов всреднем посещают центр более 2.5 раз в неделю. Есть клиенты, не посещавшие центр ни разу (вероятно только купили абонемент). Более 4 раз в неделю ходит в фитнес-центр 1% клиентов. Стандартное отклонение значительно меньше среднего и невелико по модулю (около 1), размах значений не велик.
# - Дополнительные расходы колеблятся от 0.15 до 553 у.е. 50% клиентов потратили от 68 до 210 у.е. Более 323 у.е. тратит 5% клиентов, а белее 400 - 1%. Стандартное отклонение меньше среднего но незначительно, чем и обусловлен размах значений.

# %% [markdown]
# ### Выводы:
# В датасете 4000 наблюдейний и 13 признаков (6 из них категориальные) + 1 целевая переменная. Пропусков в данных нет. Признак "количество месяцев до окончания контракта" представлен вещественным числом, но принимает три целочисленных значения 1, 6 и 12 месяцев - необходимо преобразовать. Категориальные признаки закодированы 0 и 1 - не требуют дополнительной обработки. Привязки ко времени у признаков нет.
#
# - В данных предсталены примерно равное количество записей по мужчинам и женщинам. Пол закодирован, расшифровка в документации не дана.
# - Распределение возраста клиентов имеет вид нормального. Клиентами являются люди в возрасте от 18 до 41 года. Средний возраст клиентов 29 лет. 50% клиентов от 27 до 31 года. Старше 37 лет только 1% клиентов.
# - 85% клиентов проживают в непосредственой близости к фитнес-центру. Примерно половина клиентов имеет скидку партнера. Треть клиентов пришли по приглашению друга. 90% клиентов оставляют контактный номер телефона.
# - Среди действующих абонементов 55% на месяц, 21% на 6 месяцев и  24% на 12 месяцев. Абонементом на 3 месяца не пользуется никто.
# - Распределение количества месяцев до кончания абонемента имеет ожидаемый пик на значении 1 месяц. Далее представлены все значения до 12 с пиками в 6 и 12. 13% клиентов купили абонемент на год в отчетном месяце.
# - Лайфтайм представляет собой скшенное нармальное распределение. 12% клиентов - новые, 21% являются клиентами больше месяца. Далее удержание падает. Существуют клиенты, посещающие центр более года и даже более 2 лет. Среднее время посещения центра клиентами 3 месяца, при этом более 5 месяцев спортом занимаются только 25% клиентов. Лояльность более 17 месяцев характерна только для 1% клиентов.
# - 40% клиентов посещают групповые занятия. Средняя частота посещений в неделю за все время с начала действия абонемента имеет вид нормального распределения, я выраженным ожидаемым пиков в 0 (для непосещающих групповые занятия клиентов). Средняя частота посещений колеблется от 1.77 за последний месяц до 1.88 за все время действия абонемента. 25% клиентов всреднем посещают центр более 2.5 раз в неделю. Есть клиенты, не посещавшие центр ни разу (вероятно только купили абонемент). Более 4 раз в неделю ходит в фитнес-центр 1% клиентов.
# - Расходы клиентов на дополнительный услуги ожидаемо представляют собой скошенное нормальное распределение. Есть группа, пользующаяся минимальным набором дополнительных услуг. Большая часть клиентов готова платить до 200 у.е. Далее количество клиентов устойчиво снижается. Дополнительные расходы колеблятся от 0.15 до 553 у.е. 50% клиентов потратили от 68 до 210 у.е. Более 323 у.е. тратит 5% клиентов, а белее 400 - 1%. Необычно, что нет клиентов, которые вообще не платят за доп. услуги.
# - В отток ушло 26.5% клиентов.

# %% [markdown]
# ## Предобработка данных.

# %%
# преобразуем количество месяцев до окончания контракта в целочисленный формат
df['Month_to_end_contract'] = df['Month_to_end_contract'] .astype(int)
df['Month_to_end_contract'].dtype
# Out:
# dtype('int64')

# %%
# приведем наименование колонок к нижнему регистру (в соответствие со стилем)
df.columns = df.columns.str.lower()

# %% [markdown]
# ## Исследовательский анализ данных.

# %% [markdown]
# ### Средние значения признаков.

# %%
# посмотрим на средние значения признаков для лояльных и ушедших клиентов  
df.groupby('churn').mean().T
# Out:
# churn                                  0      1
# gender                              0.51   0.51
# near_location                       0.87   0.77
# partner                             0.53   0.36
# promo_friends                       0.35   0.18
# phone                               0.90   0.90
# contract_period                     5.75   1.73
# group_visits                        0.46   0.27
# age                                29.98  26.99
# avg_additional_charges_total      158.45 115.08
# month_to_end_contract               5.28   1.66
# lifetime                            4.71   0.99
# avg_class_frequency_total           2.02   1.47
# avg_class_frequency_current_month   2.03   1.04

# %% [markdown]
# - Клиенты, попавшие в отток, всреднем реже живут рядом с фитнес-центром, реже имеют скидку партнера и друга, их средний возраст моложе на 3 года.
# - Они покупают менее длительный абонемент: 1.73 месяца против 5.75 для лояльных клиентов. Их лайфтайм всреднем не превышает года, в то время как для лояльных клиентов он составляет 4.7 года.
# - Менее 30% из них посещали групповые занятия. Центр они посещают реже: всреднем 1 раз в неделю за последний месяц и 1.47 раза в неделю за все время, лояльные клиенты всреднем приходят в центр 2 раза в неделю.
# - дополнительные траты клиентов ушедших в отток ниже 115 у.е против 158 у.е. для лояльных клиентов.
# - Пол и контактный телефон вероятно не влияет на вероятность оттока.

# %% [markdown]
# ### Гистограммы и распределения признаков.

# %%
# построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) 
# и тех, кто остался (не попали в отток)
for col in df.columns:
    plt.figure(figsize=(8, 6))
    df.query('churn == 0')[col].hist(bins=50, density=True)
    df.query('churn == 1')[col].hist(bins=50, density=True)
    plt.title(col)
    plt.xlabel('Значения переменной')
    plt.ylabel('Кол-во')
    # посчитаем долю значений
    display(df.groupby(['churn', col])[col].count() / df.groupby('churn')[col].count() * 100)
    display(df.groupby([col, 'churn'])['churn'].count() / df.groupby(col)['churn'].count() * 100)
    
    plt.show()
# Out:
# churn  gender
# 0      0        49.00
#        1        51.00
# 1      0        48.92
#        1        51.08
# Name: gender, dtype: float64
# gender  churn
# 0       0       73.51
#         1       26.49
# 1       0       73.44
#         1       26.56
# Name: churn, dtype: float64
# churn  near_location
# 0      0               12.69
#        1               87.31
# 1      0               23.19
#        1               76.81
# Name: near_location, dtype: float64
# near_location  churn
# 0              0       60.26
#                1       39.74
# 1              0       75.89
#                1       24.11
# Name: churn, dtype: float64
# churn  partner
# 0      0         46.58
#        1         53.42
# 1      0         64.47
#        1         35.53
# Name: partner, dtype: float64
# partner  churn
# 0        0       66.68
#          1       33.32
# 1        0       80.64
#          1       19.36
# Name: churn, dtype: float64
# churn  promo_friends
# 0      0               64.65
# ...

# %% [markdown]
# - Гендерный состав лояльных клиентов и ушедших в отток не различается.
# - В отток ушли 40% клиентов, проживающих далеко и только 25%, проживающих близки.
# - Только 20% клиентов с партнерской скидкой ушли в отток, для клиентов без скидки доля оттока более 30%.
# - Клиенты без скидки друга в два раза чаще уходили в отток.
# - Готовность оставить контактный телефон не влияетс на отток. Доля ушедших клиентов одинакова и составляет 26%.
# - Доля клиентов ушедших в отток падает с увеличением срока действия абонемента с 42% (1 месяц), до 2.4% (12 месяцев).
# - 17% клиентов, посещавших груповые занятия, попали в отток. Доля клиентов, не посещавших групповые занятия, и ушедших в два раза выше 33%.
# - Молодые клиенты более склонны бросать занятия спортом, чем возрастные. Доля бросивших спорт растет с 18 до 22 лет с 50 до 79% и далее плавно падает. Менее 20% клиентов старше 30 лет уходят в отток.
# - С увеличением объема потребления дополнительных платных услуг доля клиентов уходящих в отток снижается.
# - Клиенты со сроком окончания оплаченного абонемента 1 месяц - наиболее часто уходят в отток 42%. Наиболее лоялны клиенты с действующими абонементами на 3 месяца и более 7 - менее 5% уходят в отток.
# - Чем больше лайфтайм, тем меньшая доля клиентов уходит в отток. Клиенты с лайфтаймом более 10 месяцев в отток не уходили.
# - Чем чаще в неделю клиент посящает фитнес-центр, тем реже он попадает в отток.

# %% [markdown]
# ### Матрица корреляций.

# %%
# построим матрицу корреляций
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, square=True) 
plt.title('Матрица корреляций')

plt.show()

# %% [markdown]
# - Матрица корреляций выявила две пары мультиколинеарных переменных: длительность текущего действующего абонемента и срок до окончания текущего действующего абонемента, средняя частота посещений в неделю за предыдущий месяц и редняя частота посещений в неделю за все время с начала действия абонемента.
# - Матрица подтверждает, что пол и наличие контактного телефона не оказывает влияниях на отток.
# - Наибольшее влияние на отток имеют лайфтайм, средняя частота посещений в неделю за предыдущий месяц, возраст и длительность текущего действующего абонемента.

# %% [markdown]
# ## Модели прогнозирования оттока пользователей.

# %% [markdown]
# ### Предобрадобка данных для модели.

# %%
# исключим из данных малоинформативные признаки "пол", "наличие контактного телефона" и целевую переменную
X = df.drop(columns=['gender', 'phone', 'churn'], axis=1)

# зададим целевой признак — факт оттока пользователя в следующем месяце
y = df['churn']

# разделим данные на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# стандартизируем данные методом StandartScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# %% [markdown]
# ### Обучение  модели.

# %%
# задаем список моделей для обучения
models = [LogisticRegression(random_state=0),
          RandomForestClassifier(n_estimators = 1000, random_state = 0)]

# функция, которая будет выводить метрики
def print_all_metrics(y_true, y_pred, y_proba, title='Метрики классификации'):
    print(title)
    print('\tAccuracy: {:.4f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.4f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.4f}'.format(recall_score(y_true, y_pred)))
    print('\tF1: {:.4f}'.format(f1_score(y_true, y_pred)))
    print('\tROC_AUC: {:.4f}'.format(roc_auc_score(y_true, y_proba)))

# функция, которая принимает на вход модель, данные и выводит метрики
def make_prediction(model, X_train, y_train, X_test, y_test):  
    # обучим модель
    model.fit(X_train, y_train)
    # воспользуемся уже обученной моделью, чтобы сделать прогнозы
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]
    # выведем все метрики
    print_all_metrics(y_test, y_pred, y_proba, title='Метрики классификации')
    
# цикл, который выводит метрики по списку моделей
for i in models:
    print(i)
    make_prediction(model=i, 
                    X_train=X_train_st, 
                    y_train=y_train, 
                    X_test=X_test_st, 
                    y_test=y_test)
# Out:
# LogisticRegression(random_state=0)
# Метрики классификации
# 	Accuracy: 0.9237
# 	Precision: 0.8586
# 	Recall: 0.8283
# 	F1: 0.8432
# 	ROC_AUC: 0.9706
# RandomForestClassifier(n_estimators=1000, random_state=0)
# Метрики классификации
# 	Accuracy: 0.9275
# 	Precision: 0.8646
# 	Recall: 0.8384
# 	F1: 0.8513
# 	ROC_AUC: 0.9717

# %% [markdown]
# Обе модели показали себя достаточно хорошо (на количестве деревьев 100 разница не заметна).
# - Доля правильных ответов более 92% (при этом стоит помнить, что распредление клиентов у нас не 1:1, а 3:1).
# - Доля правильных ответов среди целевого класса 85.9% для логистической регрессии и 86.5% для случайного леса. Таким образом случайный лес реже отнесет в отток лояльного клиента.
# - Среди всех клиентов из оттока случайный лес обнаружил 83.8%, а логистическая регрессия 82.8%. Разница незначительна.
# - ROC_AUC достаточно высока (более 97%) с небольшим преимуществом для случайного леса, что говорит о надежности моделей.

# %% [markdown]
# ## Кластеризация пользователей.

# %% [markdown]
# ### Обучение модели.

# %%
# исключим из данных целевую переменную
X_class = df.drop(columns=['churn'], axis=1)

# стандартизация данных 
sc = StandardScaler()
X_sc = sc.fit_transform(X_class)

# %%
# построем матрицу расстояний на стандартизованной матрице признаков
linked = linkage(X_sc, method = 'ward')

# нарисуем дендрограмму
plt.figure(figsize=(15, 10))
dendrogram(linked, orientation='top')
plt.title('Hierarchial clustering for GYM')
plt.show()

# %%
# задаём число кластеров, равное 5 (по условию проекта)
km = KMeans(n_clusters = 5) 

# применяем алгоритм к данным и формируем вектор кластеров
labels = km.fit_predict(X_sc)

# %% [markdown]
# ### Анализ кластеров клиентов.

# %%
# добавляем результаты кластеризации в исходный датафрейм
df['cls'] = pd.Series(labels)
df.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                         14.23                      5
# 1             1   31                        113.20                     12
# 2             0   28                        129.45                      1
# 3             1   33                         62.67                     12
# 4             0   26                        198.36                      1
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %%
# посмотрим на средние значения признаков для разных кластеров
df.groupby('cls').mean()
# Out:
#      gender  near_location  partner  promo_friends  phone  contract_period  \
# cls
# 0      0.52           0.86     0.47           0.31   0.00             4.79
# 1      0.49           1.00     0.34           0.23   1.00             1.96
# 2      0.56           0.98     0.37           0.25   1.00             2.66
# 3      0.50           0.00     0.46           0.08   1.00             2.36
# 4      0.50           0.96     0.78           0.57   1.00            10.91
#
#      group_visits   age  avg_additional_charges_total  month_to_end_contract  \
# cls
# 0            0.43 29.30                        143.96                   4.48
# 1            0.34 28.15                        131.64                   1.86
# 2            0.47 30.11                        161.08                   2.46
# 3            0.22 28.48                        135.69                   2.21
# 4            0.55 29.98                        160.69                   9.98
#
# ...

# %%
# построим столбчатые гистограммы и распределения признаков для разных кластеров
for col in df.columns:
    plt.figure(figsize=(30, 7))
    ax = plt.subplot(1, 5, 1)
    df.query('cls == 0')[col].hist(bins=50, density=True, alpha=0.5, ax=ax)
    plt.title(f'{col}/n"кластер 0"')
    plt.xlabel('Значения переменной')
    plt.ylabel('Кол-во')
    for num in range(1,5):
        ax1 = plt.subplot(1, 5, (num+1), sharey=ax)
        df.query('cls == @num')[col].hist(bins=50, density=True, alpha=0.5, ax=ax1)
        plt.title(f'{col}/n"кластер {num}"')
        plt.xlabel('Значения переменной')
        plt.ylabel('Кол-во')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# - кластер 0. Клиенты, проживающие рядом с фитнес-клубом, преимущественно имеющие скидку партнера и все воспользовались скидкой друга. Действующий абонемент всреднем на 3 месяца. Средний лайфтайм более 3, фитнес-центр посещают всреднем менее 2 раза в неделю. Отток 25%
# - кластер 1. Клиенты, проживающие удаленно, половина из них имеют скидку партнера и редко кто пришел по рекомендации друзей. Действующий абонемент всреднем на 2 месяца. Со средним количеством посещений 2. Средний лайфтайм меньше 3, фитнес-центр посещают всреднем менее 2 раза в неделю. Отток 45%
# - кластер 2. Клиенты, преимущественно проживающие в районе фитнес-клуба, большая часть из них имеют скидку партнера, скидкиой друга воспользовались не более половины. Действующий абонемент всреднем на год. Фитнес-центр посещают всреднем 2 раза в неделю. Средний лайфтайм больше 4. Отток 2%
# - кластер 3. Клиенты, проживающие рядом с фитнес-клубом, менее четверти из них имеют скидку партнера и редко кто пришел по рекомендации друзей. Действующий абонемент всреднем на 2 месяца. Со средним лайфтаймом чуть более 2 месяцев и минимальным средним количеством посещений в неделю за месяц 1.27. Отток 53%
# - кластер 4. Клиенты, преимущественно проживающие в районе фитнес-клуба,менее четверти из них имеют скидку партнера и редко кто пришел по рекомендации друзей. Действующий абонемент всреднем на 3 месяца. Со средним лайфтаймом более 5 месяцев и максимальным средним количеством посещений в неделю за месяц 2.88. Отток 7%

# %% [markdown]
# Клиенты из кластеров 2 и 4 уходят в отток наиболее редко 2 и 7% соответственно. Клиенты кластеров 3 и 1 наиболее подвержены риску оттока 53 и 45%. Кластер 0 пограниный, 25% клиентов уходят в отток.

# %%
for col in df.drop(columns=['cls','churn'], axis=1).columns:
    display(df.groupby(['cls','churn', col])[col].count() / df.groupby(['cls','churn'])[col].count() * 100)
# Out:
# cls  churn  gender
# 0    0      0        47.87
#             1        52.13
#      1      0        47.57
#             1        52.43
# 1    0      0        53.00
#             1        47.00
#      1      0        49.77
#             1        50.23
# 2    0      0        44.61
#             1        55.39
#      1      0        42.37
#             1        57.63
# 3    0      0        50.71
#             1        49.29
#      1      0        50.00
#             1        50.00
# 4    0      0        49.95
#             1        50.05
#      1      0        39.29
#             1        60.71
# Name: gender, dtype: float64
# cls  churn  near_location
# 0    0      0                11.35
#             1                88.65
#      1      0                20.39
#             1                79.61
# 1    0      1               100.00
#      1      1               100.00
# 2    0      0                 2.38
#             1                97.62
#      1      1               100.00
# ...

# %%
df.groupby(['cls', 'churn'])['age'].mean()
# Out:
# cls  churn
# 0    0       30.09
#      1       27.15
# 1    0       29.53
#      1       26.88
# 2    0       30.26
#      1       28.10
# 3    0       29.67
#      1       26.98
# 4    0       30.08
#      1       26.68
# Name: age, dtype: float64

# %%
df.groupby(['cls', 'churn'])['avg_additional_charges_total'].mean()
# Out:
# cls  churn
# 0    0       156.76
#      1       108.92
# 1    0       150.83
#      1       113.85
# 2    0       163.91
#      1       122.76
# 3    0       149.51
#      1       118.28
# 4    0       161.73
#      1       124.51
# Name: avg_additional_charges_total, dtype: float64

# %%
df.groupby(['cls', 'churn'])['month_to_end_contract'].mean()
# Out:
# cls  churn
# 0    0        5.47
#      1        1.76
# 1    0        2.33
#      1        1.43
# 2    0        2.52
#      1        1.54
# 3    0        2.84
#      1        1.40
# 4    0       10.00
#      1        9.11
# Name: month_to_end_contract, dtype: float64

# %%
df.groupby(['cls', 'churn'])['avg_class_frequency_total'].mean()
# Out:
# cls  churn
# 0    0       1.96
#      1       1.54
# 1    0       1.09
#      1       1.37
# 2    0       2.85
#      1       2.58
# 3    0       1.86
#      1       1.41
# 4    0       1.98
#      1       1.72
# Name: avg_class_frequency_total, dtype: float64

# %%
df.groupby(['cls', 'churn'])['avg_class_frequency_current_month'].mean()
# Out:
# cls  churn
# 0    0       1.96
#      1       1.06
# 1    0       1.09
#      1       0.92
# 2    0       2.86
#      1       2.44
# 3    0       1.87
#      1       0.99
# 4    0       1.99
#      1       1.36
# Name: avg_class_frequency_current_month, dtype: float64

# %% [markdown]
# Характиристика клиентов из оттока в уязвимых сегментах и лояльных клиентов в надежных.
# - Кластер 0. Все клиенты из оттока проживают рядом с клубом. 81% клиентов из оттока имели скидку партнера. Все клиенты из оттока воспользовались скидкой друга. 80% клиентов из оттока купили абонемент на 1 месяц, 20% на 6. 64 % клиентов из оттока не посещали групповые занятия (против 51% лояльных). Всреднем у клиентов из оттока до окончания контракта оастается 1.86 месяца (для лояльных этот показатель в 2 раза выше 3.3).
# - Кластер 1. Все клиенты из оттока проживают не рядом с клубом. 40% клиентов имели скидку партнера (среди лояльных клиентов скидку партнера применили 52%). Скидкой друга воспользовались 4% клиентов из оттока и 10% лояльных. 90% клиентов из оттока купили абонемент на 1 месяц, 7% на 6. 82 % клиентов из оттока не посещали групповые занятия (против 75% лояльных). Всреднем у клиентов из оттока до окончания контракта оастается 1.4 месяца (для лояльных этот показатель в 2 раза выше 2.6).
# - Кластер 2. Скидкой партнера воспользовались более 73% лояльных клиентов. Скидкой друга воспользовались 49% лояльных. 98% лояльных клиентов купили абонемент на 12 месяцев. 55% лояльных клиентов посещают групповые занятия.
# - Кластер 3. Все клиенты из оттока проживают рядом с клубом. Скидкой друга воспользовались 3% клиентов из оттока. 90% клиентов из оттока купили абонемент на 1 месяц, 8% на 6. 74 % клиентов из оттока не посещали групповые занятия (против 61% лояльных). Всреднем у клиентов из оттока до окончания контракта оастается 1.4 месяца (для лояльных этот показатель выше - 2.5).
# - Кластер 4. Скидкой партнера пользуются 26% лояльных клиентов. Скидкой друга воспользовались 1.9% клиентов из оттока и 9.5% лояльных. 83% клиентов из оттока купили абонемент на 1 месяц, 17% на 6. 48% лояльных клиентов посещают групповые занятия.
#
# Сумма дополнительных трат всреднем чуть больше для лояльных клиентов, чем для ушедших в отток во всех кластерах. То есть нельзя сказать, что клиенты уходят от нас из-за высоких цен на дополнительные услуги. Наоборот средние траты лояльных клиентов из надежных кластеров выше, чем из кластеров с высоким оттоком.
#
# У клиентов всех кластеров отмечено снижение среднего количества посещений в неделю за последний месяц по сравнению с показателем за весь период посещения клуба. Клиенты из надежных кластеров всреднем ходят 2 и более раза в неделю. Клиенты из кластеров риска ушедшие в отток всреднем посещали менее 1,5 раз в неделю.

# %% [markdown]
# ## Выводы и рекомендации по работе с клиентами.

# %% [markdown]
# Мы провели исследование оттока клиентов для сети фитнес-центров «Культурист-датасаентист». Данные из анкет пользователей на месяц до оттока и факт оттока на определённый месяц предоставил отдел по работе с клиентами.
#
# Пропусков в данных не было, привязки ко времени нет. Мы провели минимальную предобработку, преобразовав вещественный тип в целочисленный для признака "количество месяцев до окончания контракта" (данные были представлены целым числом, в качестве не потеряли) и приведя названия признаков к нижнему регистру.
#
# **Портрет клиента.**
#
# В датасете 4000 наблюдейний и 13 признаков (6 из них категориальные) + 1 целевая переменная(`churn`):
# - `gender` — пол. В данных предсталены примерно равное количество записей по мужчинам и женщинам. Пол закодирован, расшифровка в документации не дана.
# - `Near_Location` — проживание или работа в районе, где находится фитнес-центр. 85% клиентов проживают в непосредственой близости к фитнес-центру.
# - `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента). Примерно половина клиентов имеет скидку партнера.
# - `Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента). Треть клиентов пришли по приглашению друга.
# - `Phone` — наличие контактного телефона. 90% клиентов оставляют контактный номер телефона.
# - `Age` — возраст. Распределение возраста клиентов имеет вид нормального. Клиентами являются люди в возрасте от 18 до 41 года. Средний возраст клиентов 29 лет. 50% клиентов от 27 до 31 года. Старше 37 лет только 1% клиентов.
# - `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах). Лайфтайм представляет собой скошенное нармальное распределение. 12% клиентов - новые, 21% являются клиентами больше месяца. Далее удержание падает. Существуют клиенты, посещающие центр более года и даже более 2 лет. Среднее время посещения центра клиентами 3 месяца, при этом более 5 месяцев спортом занимаются только 25% клиентов. Лояльность более 17 месяцев характерна только для 1% клиентов.
# - `Contract_period` — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год). Среди действующих абонементов 55% на месяц, 21% на 6 месяцев и  24% на 12 месяцев. Абонементом на 3 месяца не пользуется никто.
# - `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах). Распределение количества месяцев до кончания абонемента имеет ожидаемый пик на значении 1 месяц. Далее представлены все значения до 12 с пиками в 6 и 12. 13% клиентов купили абонемент на год в отчетном месяце.
# - `Group_visits` — факт посещения групповых занятий. 40% клиентов посещают групповые занятия.
# - `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента. Средняя частота посещений в неделю за все время с начала действия абонемента имеет вид нормального распределения, с выраженным ожидаемым пиком в 0. Средняя частота посещений колеблется от 1.77 за последний месяц до 1.88 за все время действия абонемента. 25% клиентов всреднем посещают центр более 2.5 раз в неделю. Есть клиенты, не посещавшие центр ни разу (вероятно только купили абонемент). Более 4 раз в неделю ходит в фитнес-центр 1% клиентов.
# - `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц.
# - `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон. Расходы клиентов на дополнительный услуги ожидаемо представляют собой скошенное нормальное распределение. Есть группа, пользующаяся минимальным набором дополнительных услуг. Большая часть клиентов готова платить до 200 у.е. Далее количество клиентов устойчиво снижается. Дополнительные расходы колеблятся от 0.15 до 553 у.е. 50% клиентов потратили от 68 до 210 у.е. Более 323 у.е. тратит 5% клиентов, а белее 400 - 1%. Необычно, что нет клиентов, которые вообще не платят за доп. услуги.
# - В отток ушло 26.5% клиентов.
#
# **Клиенты, попавшие в отток**:
# - Всреднем реже живут рядом с фитнес-центром (В отток ушли 40% клиентов, проживающих далеко и только 25%, проживающих близко),
# - Реже имеют скидку партнера (Только 20% клиентов с партнерской скидкой ушли в отток, для клиентов без скидки доля оттока более 30%) и друга (Клиенты без скидки друга в два раза чаще уходили в отток),
# - Их средний возраст моложе на 3 года. Молодые клиенты более склонны бросать занятия спортом, чем возрастные. Доля бросивших спорт растет с 18 до 22 лет с 50 до 79% и далее плавно падает. Менее 20% клиентов старше 30 лет уходят в отток.
# - Они покупают менее длительный абонемент: 1.73 месяца против 5.75 для лояльных клиентов. Доля клиентов ушедших в отток падает с увеличением срока действия абонемента с 42% (1 месяц), до 2.4% (12 месяцев). Клиенты со сроком окончания оплаченного абонемента 1 месяц - наиболее часто уходят в отток 42%. Наиболее лоялны клиенты с действующими абонементами на 3 месяца и более 7 - менее 5% уходят в отток.
# - Их лайфтайм всреднем не превышает года, в то время как для лояльных клиентов он составляет 4.7 года. Клиенты с лайфтаймом более 10 месяцев в отток не уходили.
# - Менее 30% из них посещали групповые занятия. Доля клиентов, не посещавших групповые занятия и ушедших в отток, в два раза выше чем посещавших 33%.
# - Центр они посещают реже: всреднем 1 раз в неделю за последний месяц и 1.47 раза в неделю за все время, лояльные клиенты всреднем приходят в центр 2 раза в неделю.
# - Средние дополнительные траты клиентов ушедших в отток ниже 115 у.е против 158 у.е. для лояльных клиентов. С увеличением объема потребления дополнительных платных услуг доля клиентов уходящих в отток снижается.
# - Пол и контактный телефон вероятно не влияет на вероятность оттока.
#
#
# ** Прогноз оттока.**
#
# Мы построили две модели прогнозирования оттока клиентов на имеющихся данных (разделив их на тестовые и обучающие) логистическая регрессия и случайный лес. Обе модели показали себя достаточно хорошо (на количестве деревьев 100 разница не заметна) с небольшим преимуществом случайного леса.
# - Доля правильных ответов более 92% (при этом стоит помнить, что распредление клиентов у нас не 1:1, а 3:1).
# - Доля правильных ответов среди целевого класса 85.9% для логистической регрессии и 86.5% для случайного леса. Таким образом случайный лес реже отнесет в отток лояльного клиента.
# - Среди всех клиентов из оттока случайный лес обнаружил 83.8%, а логистическая регрессия 82.8%. Разница незначительна.
# - ROC_AUC достаточно высока (более 97%) с небольшим преимуществом для случайного леса, что говорит о надежности моделей.
#
#
# ** Кластеризация клиентов**
# - кластер 0. Клиенты, проживающие рядом с фитнес-клубом, преимущественно имеющие скидку партнера и все воспользовались скидкой друга. Действующий абонемент всреднем на 3 месяца. Средний лайфтайм более 3, фитнес-центр посещают всреднем менее 2 раза в неделю. Отток 25%
# - кластер 1. Клиенты, проживающие удаленно, половина из них имеют скидку партнера и редко кто пришел по рекомендации друзей. Действующий абонемент всреднем на 2 месяца. Со средним количеством посещений 2. Средний лайфтайм меньше 3, фитнес-центр посещают всреднем менее 2 раза в неделю. Отток 45%
# - кластер 2. Клиенты, преимущественно проживающие в районе фитнес-клуба, большая часть из них имеют скидку партнера, скидкиой друга воспользовались не более половины. Действующий абонемент всреднем на год. Фитнес-центр посещают всреднем 2 раза в неделю. Средний лайфтайм больше 4. Отток 2%
# - кластер 3. Клиенты, проживающие рядом с фитнес-клубом, менее четверти из них имеют скидку партнера и редко кто пришел по рекомендации друзей. Действующий абонемент всреднем на 2 месяца. Со средним лайфтаймом чуть более 2 месяцев и минимальным средним количеством посещений в неделю за месяц 1.27. Отток 53%
# - кластер 4. Клиенты, преимущественно проживающие в районе фитнес-клуба,менее четверти из них имеют скидку партнера и редко кто пришел по рекомендации друзей. Действующий абонемент всреднем на 3 месяца. Со средним лайфтаймом более 5 месяцев и максимальным средним количеством посещений в неделю за месяц 2.88. Отток 7%
#
# Клиенты из кластеров 2 и 4 уходят в отток наиболее редко 2 и 7% соответственно. Клиенты кластеров 3 и 1 наиболее подвержены риску оттока 53 и 45%. Кластер 0 пограничный, 25% клиентов уходят в отток.
#
# Характиристика клиентов из оттока в уязвимых сегментах и лояльных клиентов в надежных.
# - Кластер 0. Все клиенты из оттока проживают рядом с клубом. 81% клиентов из оттока имели скидку партнера. Все клиенты из оттока воспользовались скидкой друга. 80% клиентов из оттока купили абонемент на 1 месяц, 20% на 6. 64 % клиентов из оттока не посещали групповые занятия (против 51% лояльных). Всреднем у клиентов из оттока до окончания контракта остается 1.86 месяца (для лояльных этот показатель в 2 раза выше 3.3).
# - Кластер 1. Все клиенты из оттока проживают не рядом с клубом. 40% клиентов имели скидку партнера (среди лояльных клиентов скидку партнера применили 52%). Скидкой друга воспользовались 4% клиентов из оттока и 10% лояльных. 90% клиентов из оттока купили абонемент на 1 месяц, 7% на 6. 82 % клиентов из оттока не посещали групповые занятия (против 75% лояльных). Всреднем у клиентов из оттока до окончания контракта остается 1.4 месяца (для лояльных этот показатель в 2 раза выше 2.6).
# - Кластер 2. Скидкой партнера воспользовались более 73% лояльных клиентов. Скидкой друга воспользовались 49% лояльных. 98% лояльных клиентов купили абонемент на 12 месяцев. 55% лояльных клиентов посещают групповые занятия.
# - Кластер 3. Все клиенты из оттока проживают рядом с клубом. Скидкой друга воспользовались 3% клиентов из оттока. 90% клиентов из оттока купили абонемент на 1 месяц, 8% на 6. 74 % клиентов из оттока не посещали групповые занятия (против 61% лояльных). Всреднем у клиентов из оттока до окончания контракта оастается 1.4 месяца (для лояльных этот показатель выше - 2.5).
# - Кластер 4. Скидкой партнера пользуются 26% лояльных клиентов. Скидкой друга воспользовались 1.9% клиентов из оттока и 9.5% лояльных. 83% клиентов из оттока купили абонемент на 1 месяц, 17% на 6. 48% лояльных клиентов посещают групповые занятия.
#
# Сумма дополнительных трат всреднем чуть больше для лояльных клиентов, чем для ушедших в отток во всех кластерах. То есть нельзя сказать, что клиенты уходят от нас из-за высоких цен на дополнительные услуги. Наоборот средние траты лояльных клиентов из надежных кластеров выше, чем из кластеров с высоким оттоком.
#
# У клиентов всех кластеров отмечено снижение среднего количества посещений в неделю за последний месяц по сравнению с показателем за весь период посещения клуба. Клиенты из надежных кластеров всреднем ходят 2 и более раза в неделю. Клиенты из кластеров риска ушедшие в отток всреднем посещали менее 1,5 раз в неделю.

# %% [markdown]
# Для повышения удержания клиентов рекомендуется:
# - Провести исследование среди клиентов кластеров 0,1 и 3 о причиных отказа от групповых занятий: отсутсвие информации\ неудобный график \ отсутствует интересующее направление и т.д.  По результатам рассмотреть возможность корректировки политики клуба.
# - Разработать меры стимулирования для клиентов, посещающих клуб менее 1,5 раз в неделю, и клиентов, у которых упала интенсивность еженедельных посещений за последний месяц по сравнению с данными за весь период. Например, выдавать промо-флаеры на бесплатный сок\воду\яблоко в баре для тех, кто придет на этой неделе 2(3)ий раз. Приглашать на дополнительные мастер-классы\посещение банной зоны и т.д. Клиентам из кластеров 1 и 3 возможно выдавать\рассказывать о скидке друга (для клиентов из кластера о данная мера наврядли будет эффективной).
# - Особое внимание уделять клиентам до 27 лет, они наиболее часто уходят в отток во всех кластерах.
